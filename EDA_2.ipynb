# %%
import pickle
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline
import seaborn as sns

# %%
#Importing clean data
pickleFile = open('X_dummies.pickle', 'rb')
X = pickle.load(pickleFile)
pickleFile.close()

pickleFile = open('y.pickle', 'rb')
y = pickle.load(pickleFile)
pickleFile.close()

#Read
pickleFile = open('cat_df_buildings.pickle', 'rb')
cat_df_buildings = pickle.load(pickleFile)
pickleFile.close()

# %% [markdown]
# #### Investigating the relation between categorical features and the targuet

# %%
#Boxplot damage_grade and foundation_type
cat_df_buildings.boxplot('damage_grade','foundation_type',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='foundation_type'>

# %%
#Boxplot damage_grade and roof_type
cat_df_buildings.boxplot('damage_grade','roof_type',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='roof_type'>

# %%
#Boxplot damage_grade and ground_floor_type
cat_df_buildings.boxplot('damage_grade','ground_floor_type',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='ground_floor_type'>

# %%
#Boxplot damage_grade and position
cat_df_buildings.boxplot('damage_grade','position',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='position'>

# %%
#Boxplot damage_grade and plan_configuration
cat_df_buildings.boxplot('damage_grade','plan_configuration',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='plan_configuration'>

# %%
#Boxplot damage_grade and legal_ownership_status
cat_df_buildings.boxplot('damage_grade','legal_ownership_status',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='legal_ownership_status'>

# %%
#Boxplot damage_grade and legal_ownership_status
cat_df_buildings.boxplot('damage_grade','legal_ownership_status',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='legal_ownership_status'>

# %%
#Boxplot damage_grade and legal_ownership_status
cat_df_buildings.boxplot('damage_grade','legal_ownership_status',rot = 30,figsize=(5,6))
# Out:
# <AxesSubplot:title={'center':'damage_grade'}, xlabel='legal_ownership_status'>

# %%
#Frequency distribution of categories
print(cat_df_buildings['foundation_type'].value_counts())
# Out:
# r    219196
# w     15118
# u     14260
# i     10579
# h      1448
# Name: foundation_type, dtype: int64

# %%
print(cat_df_buildings['roof_type'].value_counts())
# Out:
# n    182842
# q     61576
# x     16183
# Name: roof_type, dtype: int64

# %%
print(cat_df_buildings['ground_floor_type'].value_counts())
# Out:
# f    209619
# x     24877
# v     24593
# z      1004
# m       508
# Name: ground_floor_type, dtype: int64

# %%
print(cat_df_buildings['other_floor_type'].value_counts())
# Out:
# q    165282
# x     43448
# j     39843
# s     12028
# Name: other_floor_type, dtype: int64

# %%
print(cat_df_buildings['position'].value_counts())
# Out:
# s    202090
# t     42896
# j     13282
# o      2333
# Name: position, dtype: int64

# %%
print(cat_df_buildings['plan_configuration'].value_counts())
# Out:
# d    250072
# q      5692
# u      3649
# s       346
# c       325
# a       252
# o       159
# m        46
# n        38
# f        22
# Name: plan_configuration, dtype: int64

# %%
print(cat_df_buildings['legal_ownership_status'].value_counts())
# Out:
# v    250939
# a      5512
# w      2677
# r      1473
# Name: legal_ownership_status, dtype: int64

# %% [markdown]
# #### Investigating the relationship between numerical features and the targuet

# %%
selected_features = ['area_percentage', 
                     'height_percentage',
                     'count_floors_pre_eq']

train_values_subset = X[selected_features]

# %%
sns.pairplot(train_values_subset.join(y), 
             hue='damage_grade')
