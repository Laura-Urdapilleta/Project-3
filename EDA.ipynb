# %%
import pickle
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline
import seaborn as sns

# %%
#Importing clean data
pickleFile = open('X_dummies.pickle', 'rb')
X = pickle.load(pickleFile)
pickleFile.close()

pickleFile = open('y.pickle', 'rb')
y = pickle.load(pickleFile)
pickleFile.close()

# %% [markdown]
# ### Class Imbalance

# %%
(y.damage_grade
  .value_counts()
  .sort_index()
  .plot.bar(title="Number of Buildings with Each Damage Grade"))
# Out:
# <AxesSubplot:title={'center':'Number of Buildings with Each Damage Grade'}>

# %% [markdown]
# #### Ploting the distribution of some of my features

# %%
X.head()
# Out:
#         geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 57361               10            1074            8048                    3
# 83075                8             463            5839                    1
# 86173               26            1050            8829                    2
# 258337              20             497            1885                    2
# 51055               17             198           12174                    3
#
#         age  area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 57361    85               10                  8                             0
# 83075    20               10                  3                             1
# 86173    10                8                  5                             0
# 258337   30                6                  5                             0
# 51055    60                7                 10                             0
#
# ...

# %%
# Plot the histogram
geo_level_1_id = X['geo_level_1_id']
plt.hist(geo_level_1_id)

# Label the axes
plt.xlabel('geo_level_id_1')
plt.ylabel('Frequency')

# Show the figure
plt.show()

# %%
# Plot the histogram
count_floors_pre_eq = X['count_floors_pre_eq']
plt.hist(count_floors_pre_eq)

# Label the axes
plt.xlabel('count_floors_pre_eq')
plt.ylabel('Frequency')

# Show the figure
plt.show()

# %%
# Plot the histogram
age = X['age']
plt.hist(age)

# Label the axes
plt.xlabel('age')
plt.ylabel('Frequency')

# Show the figure
plt.show()

# %%
# Plot the histogram
area_percentage = X['area_percentage']
plt.hist(area_percentage)

# Label the axes
plt.xlabel('area_percentage')
plt.ylabel('Frequency')

# Show the figure
plt.show()

# %%
# Plot the histogram
height_percentage = X['height_percentage']
plt.hist(height_percentage)

# Label the axes
plt.xlabel('height_percentage')
plt.ylabel('Frequency')

# Show the figure
plt.show()

# %%
# Plot the histogram
count_families = X['count_families']
plt.hist(height_percentage)

# Label the axes
plt.xlabel('count_families')
plt.ylabel('Frequency')

# Show the figure
plt.show()
